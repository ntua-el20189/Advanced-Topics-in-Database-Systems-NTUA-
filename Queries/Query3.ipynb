# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, count, desc, rank, sum as _sum
from pyspark.sql.types import *
from pyspark.sql.window import Window

# Start Spark Session
spark = SparkSession.builder \
    .appName("Query 3") \
    .config("spark.executor.memory", "4g") \
    .config("spark.executor.cores", "4") \
    .getOrCreate()
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>2568</td><td>application_1732639283265_2527</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-36.eu-central-1.compute.internal:20888/proxy/application_1732639283265_2527/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-16.eu-central-1.compute.internal:8042/node/containerlogs/container_1732639283265_2527_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# paths
crime_data_2010_2019 = "s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2010_to_2019_20241101.csv"
crime_data_2020 = "s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2020_to_Present_20241101.csv"
income_data = "s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv"
census_blocks = "s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson"

# Load datasets
crime_data = spark.read.csv(crime_data_2010_2019, header=True, inferSchema=True).union(
    spark.read.csv(crime_data_2020, header=True, inferSchema=True))
income_data = spark.read.csv(income_data, header=True, inferSchema=True)
census_data = spark.read.json(census_blocks)
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>2649</td><td>application_1732639283265_2608</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-36.eu-central-1.compute.internal:20888/proxy/application_1732639283265_2608/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-80.eu-central-1.compute.internal:8042/node/containerlogs/container_1732639283265_2608_01_000002/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
from sedona.spark import *
from pyspark.sql.functions import col
from pyspark.sql import SparkSession

# # Create spark Session
# spark = SparkSession.builder \
#     .appName("GeoJSON read") \
#     .getOrCreate()

# Create sedona context
sedona = SedonaContext.create(spark)
blocks_data = sedona.read.format("geojson") \
            .option("multiLine", "true").load(census_blocks) \
            .selectExpr("explode(features) as features") \
            .select("features.*")
# Formatting magic
flattened_data = blocks_data.select( \
                [col(f"properties.{col_name}").alias(col_name) for col_name in \
                blocks_data.schema["properties"].dataType.fieldNames()] + ["geometry"]) \
            .drop("properties") \
            .drop("type")
# Print schema
flattened_data.printSchema()

#flattened_data.show(2)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- BG10: string (nullable = true)
#  |-- BG10FIP10: string (nullable = true)
#  |-- BG12: string (nullable = true)
#  |-- CB10: string (nullable = true)
#  |-- CEN_FIP13: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- CITYCOM: string (nullable = true)
#  |-- COMM: string (nullable = true)
#  |-- CT10: string (nullable = true)
#  |-- CT12: string (nullable = true)
#  |-- CTCB10: string (nullable = true)
#  |-- HD_2012: long (nullable = true)
#  |-- HD_NAME: string (nullable = true)
#  |-- HOUSING10: long (nullable = true)
#  |-- LA_FIP10: string (nullable = true)
#  |-- OBJECTID: long (nullable = true)
#  |-- POP_2010: long (nullable = true)
#  |-- PUMA10: string (nullable = true)
#  |-- SPA_2012: long (nullable = true)
#  |-- SPA_NAME: string (nullable = true)
#  |-- SUP_DIST: string (nullable = true)
#  |-- SUP_LABEL: string (nullable = true)
#  |-- ShapeSTArea: double (nullable = true)
#  |-- ShapeSTLength: double (nullable = true)
#  |-- ZCTA10: string (nullable = true)
#  |-- geometry: geometry (nullable = true)

# %%
from pyspark.sql.functions import col, sum as _sum
from pyspark.sql.functions import col, sum as _sum, expr
from pyspark.sql.functions import regexp_replace, col

# 1. Normalize and Aggregate Population Data
# Aggregate population data by ZCTA10
population_data = flattened_data.select(
    col("ZCTA10").alias("Zip_Code"),
    col("POP_2010").alias("Population")
).groupBy("Zip_Code").agg(_sum("Population").alias("Total_Population"))

# Show the result to verify
population_data.show(5, truncate=False)

income_data = income_data.withColumnRenamed("Estimated Median Income", "Median_Income") \
                     .withColumnRenamed("Zip Code", "Zip_Code") \
                     .withColumn("Median_Income", regexp_replace(col("Median_Income"), "[$,]", "").cast("double"))

# Show the result to verify
income_data.show(5, truncate=False)

# Aggregate crimes by area name
crime_areas_data = crime_data.groupBy("AREA NAME").agg({"DR_NO": "count"}).withColumnRenamed("count(DR_NO)", "Total_Crimes")

# Show the result to verify
crime_areas_data.show(5, truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------+----------------+
# |Zip_Code|Total_Population|
# +--------+----------------+
# |90807   |31481           |
# |91326   |33708           |
# |90094   |5464            |
# |91766   |66902           |
# |90026   |67869           |
# +--------+----------------+
# only showing top 5 rows
#
# +--------+--------------------------------------------------------------------------------------------+-------------+
# |Zip_Code|Community                                                                                   |Median_Income|
# +--------+--------------------------------------------------------------------------------------------+-------------+
# |90001   |Los Angeles (South Los Angeles), Florence-Graham                                            |33887.0      |
# |90002   |Los Angeles (Southeast Los Angeles, Watts)                                                  |30413.0      |
# |90003   |Los Angeles (South Los Angeles, Southeast Los Angeles)                                      |30805.0      |
# |90004   |Los Angeles (Hancock Park, Rampart Village, Virgil Village, Wilshire Center, Windsor Square)|40612.0      |
# |90005   |Los Angeles (Hancock Park, Koreatown, Wilshire Center, Wilshire Park, Windsor Square)       |31142.0      |
# +--------+--------------------------------------------------------------------------------------------+-------------+
# only showing top 5 rows
#
# +-----------+------------+
# |AREA NAME  |Total_Crimes|
# +-----------+------------+
# |Harbor     |133031      |
# |N Hollywood|164710      |
# |Van Nuys   |142327      |
# |West Valley|131585      |
# |Wilshire   |136374      |
# +-----------+------------+
# only showing top 5 rows

# %%
#create geometry points for crimes using LAT and LON
crime_data = crime_data.withColumn("geom", ST_Point("LON", "LAT"))

# Aggregate geometries by ZIP code
zip_geometries = flattened_data.groupBy("ZCTA10").agg(
    ST_Union_Aggr("geometry").alias("geometry")
).withColumnRenamed("ZCTA10", "Zip_Code")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# # Join crimes with ZIP code geometries using ST_Within
# crime_with_zip = crime_data.join(
#     zip_geometries,
#     ST_Within(crime_data["geom"], zip_geometries["geometry"]),
#     "inner"
# )

# # Aggregate total crimes by ZIP code
# crime_by_zip = crime_with_zip.groupBy("Zip_Code").agg( count("DR_NO").alias("Total_Crimes") )

# # Join population and income data
# pop_income_data = population_data.join(income_data, on="Zip_Code", how="inner")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Geospatial join: Assign ZIP codes to AREA NAMEs using crime data
zip_to_area = crime_data.select("AREA NAME", "geom").join(
    zip_geometries,
    ST_Within(crime_data["geom"], zip_geometries["geometry"]),
    "inner"
).select("Zip_Code", "AREA NAME").distinct()

# Show the mapping
zip_to_area.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------+----------+
# |Zip_Code| AREA NAME|
# +--------+----------+
# |   90266|Hollenbeck|
# |   90008|  Wilshire|
# |   90045|    Harbor|
# |   90304|   Pacific|
# |   90024|   Pacific|
# |   90404|    Newton|
# |   90232|  Wilshire|
# |   90073|   West LA|
# |   90403|  Wilshire|
# |   90245|   Olympic|
# |   90401|Hollenbeck|
# |   90049|   West LA|
# |   90302|   Pacific|
# |   90405|   Pacific|
# |   90405|   Central|
# |   90043|   Pacific|
# |   90245|   Pacific|
# |   90018| Southwest|
# |   90291|   Olympic|
# |   90005|  Wilshire|
# +--------+----------+
# only showing top 20 rows

# %%
# Combine geospatial join and crime aggregation
zip_to_area_crime = crime_data.join(
    zip_geometries,
    ST_Within(crime_data["geom"], zip_geometries["geometry"]),
    "inner"
).groupBy("Zip_Code", "AREA NAME").agg(
    count("DR_NO").alias("Total_Crimes")
)

# Show results for verification
# zip_to_area_crime.show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Join ZIP code-based population and income with crime data
area_population_income = zip_to_area_crime.join(population_data, on="Zip_Code", how="inner") \
    .join(income_data, on="Zip_Code", how="inner")

# Aggregate total population, average income, and crimes by AREA NAME
final_area_data = area_population_income.groupBy("AREA NAME").agg(
    _sum("Total_Population").alias("Total_Population"),
    (_sum("Median_Income") / _sum("Total_Population")).alias("Avg_Income_Per_Person"),
    _sum("Total_Crimes").alias("Total_Crimes")
)

# Show results for verification
# final_area_data.show(truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Calculate metrics: Average income per person and crimes per person
metrics_by_area = final_area_data.select(
    col("AREA NAME"),
    col("Avg_Income_Per_Person"),
    (col("Total_Crimes") / col("Total_Population")).alias("Crimes_Per_Person")
)

# Show the final result
metrics_by_area.show(truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------+---------------------+-------------------+
# |AREA NAME  |Avg_Income_Per_Person|Crimes_Per_Person  |
# +-----------+---------------------+-------------------+
# |Harbor     |1.4934860695460446   |0.0566400113534792 |
# |N Hollywood|1.3563236944348895   |0.11537073481563351|
# |Van Nuys   |1.912627858121802    |0.12540546833246022|
# |West Valley|1.7451880929912311   |0.10015834679547672|
# |Wilshire   |1.5595552388254463   |0.0876788768698825 |
# |Topanga    |1.8691518914045722   |0.11288243232127776|
# |Foothill   |1.6931473127605596   |0.09648812181490662|
# |Devonshire |1.4373115668557885   |0.10632421404220281|
# |Pacific    |1.5193721551315027   |0.0457701780115032 |
# |Central    |1.2982976174407537   |0.07162145829528843|
# |West LA    |2.518749265028811    |0.10631103260752178|
# |Northeast  |1.4655195533922605   |0.08425209474024864|
# |Mission    |1.457785754352768    |0.09859339630219838|
# |Southeast  |0.978406514446836    |0.07837444443200792|
# |Olympic    |1.6105674771799032   |0.10683180560652891|
# |Southwest  |1.2897477408777571   |0.08648157490560059|
# |Rampart    |1.3334276857649796   |0.0938562759325357 |
# |77th Street|1.0924050632911393   |0.1178531736759015 |
# |Hollywood  |1.6293112264614198   |0.11762010228513836|
# |Newton     |1.1768343293492696   |0.0869503207825973 |
# +-----------+---------------------+-------------------+
# only showing top 20 rows

# %%
# Explain the query plan
metrics_by_area.explain(mode="formatted")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan (44)
# +- HashAggregate (43)
#    +- Exchange (42)
#       +- HashAggregate (41)
#          +- Project (40)
#             +- BroadcastHashJoin Inner BuildRight (39)
#                :- Project (34)
#                :  +- SortMergeJoin Inner (33)
#                :     :- Sort (23)
#                :     :  +- Exchange (22)
#                :     :     +- HashAggregate (21)
#                :     :        +- Exchange (20)
#                :     :           +- HashAggregate (19)
#                :     :              +- Project (18)
#                :     :                 +- RangeJoin (17)
#                :     :                    :- Union (7)
#                :     :                    :  :- Project (3)
#                :     :                    :  :  +- Filter (2)
#                :     :                    :  :     +- Scan csv  (1)
#                :     :                    :  +- Project (6)
#                :     :                    :     +- Filter (5)
#                :     :                    :        +- Scan csv  (4)
#                :     :                    +- Filter (16)
#                :     :                       +- ObjectHashAggregate (15)
#                :     :                          +- Exchange (14)
#                :     :                             +- ObjectHashAggregate (13)
#                :     :                                +- Project (12)
#                :     :                                   +- Filter (11)
#                :     :                                      +- Generate (10)
#                :     :                                         +- Filter (9)
#                :     :                                            +- Scan geojson  (8)
#                :     +- Sort (32)
#                :        +- HashAggregate (31)
#                :           +- Exchange (30)
#                :              +- HashAggregate (29)
#                :                 +- Project (28)
#                :                    +- Filter (27)
#                :                       +- Generate (26)
#                :                          +- Filter (25)
#                :                             +- Scan geojson  (24)
#                +- BroadcastExchange (38)
#                   +- Project (37)
#                      +- Filter (36)
#                         +- Scan csv  (35)
#
#
# (1) Scan csv
# Output [4]: [DR_NO#29, AREA NAME#34, LAT#55, LON#56]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2010_to_2019_20241101.csv]
# ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#
# (2) Filter
# Input [4]: [DR_NO#29, AREA NAME#34, LAT#55, LON#56]
# Condition : isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#
# (3) Project
# Output [3]: [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
# Input [4]: [DR_NO#29, AREA NAME#34, LAT#55, LON#56]
#
# (4) Scan csv
# Output [4]: [DR_NO#103, AREA NAME#108, LAT#129, LON#130]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_Data_from_2020_to_Present_20241101.csv]
# ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#
# (5) Filter
# Input [4]: [DR_NO#103, AREA NAME#108, LAT#129, LON#130]
# Condition : isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#
# (6) Project
# Output [3]: [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1935]
# Input [4]: [DR_NO#103, AREA NAME#108, LAT#129, LON#130]
#
# (7) Union
#
# (8) Scan geojson
# Output [1]: [features#996]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (9) Filter
# Input [1]: [features#996]
# Condition : ((size(features#996, true) > 0) AND isnotnull(features#996))
#
# (10) Generate
# Input [1]: [features#996]
# Arguments: explode(features#996), false, [features#1004]
#
# (11) Filter
# Input [1]: [features#1004]
# Condition : isnotnull(features#1004.properties.ZCTA10)
#
# (12) Project
# Output [2]: [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
# Input [1]: [features#1004]
#
# (13) ObjectHashAggregate
# Input [2]: [ZCTA10#1037, geometry#1007]
# Keys [1]: [ZCTA10#1037]
# Functions [1]: [partial_st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)]
# Aggregate Attributes [1]: [buf#1351]
# Results [2]: [ZCTA10#1037, buf#1352]
#
# (14) Exchange
# Input [2]: [ZCTA10#1037, buf#1352]
# Arguments: hashpartitioning(ZCTA10#1037, 1000), ENSURE_REQUIREMENTS, [plan_id=4785]
#
# (15) ObjectHashAggregate
# Input [2]: [ZCTA10#1037, buf#1352]
# Keys [1]: [ZCTA10#1037]
# Functions [1]: [st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)]
# Aggregate Attributes [1]: [ST_Union_Aggr(geometry#1007)#1312]
# Results [2]: [ZCTA10#1037 AS Zip_Code#1328, ST_Union_Aggr(geometry#1007)#1312 AS geometry#1313]
#
# (16) Filter
# Input [2]: [Zip_Code#1328, geometry#1313]
# Condition : isnotnull(geometry#1313)
#
# (17) RangeJoin
# Arguments: geom#1253: geometry, geometry#1313: geometry, WITHIN
#
# (18) Project
# Output [3]: [DR_NO#29, AREA NAME#34, Zip_Code#1328]
# Input [5]: [DR_NO#29, AREA NAME#34, geom#1253, Zip_Code#1328, geometry#1313]
#
# (19) HashAggregate
# Input [3]: [DR_NO#29, AREA NAME#34, Zip_Code#1328]
# Keys [2]: [Zip_Code#1328, AREA NAME#34]
# Functions [1]: [partial_count(DR_NO#29)]
# Aggregate Attributes [1]: [count#1865L]
# Results [3]: [Zip_Code#1328, AREA NAME#34, count#1866L]
#
# (20) Exchange
# Input [3]: [Zip_Code#1328, AREA NAME#34, count#1866L]
# Arguments: hashpartitioning(Zip_Code#1328, AREA NAME#34, 1000), ENSURE_REQUIREMENTS, [plan_id=4791]
#
# (21) HashAggregate
# Input [3]: [Zip_Code#1328, AREA NAME#34, count#1866L]
# Keys [2]: [Zip_Code#1328, AREA NAME#34]
# Functions [1]: [count(DR_NO#29)]
# Aggregate Attributes [1]: [count(DR_NO#29)#1806L]
# Results [3]: [Zip_Code#1328, AREA NAME#34, count(DR_NO#29)#1806L AS Total_Crimes#1807L]
#
# (22) Exchange
# Input [3]: [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L]
# Arguments: hashpartitioning(Zip_Code#1328, 1000), ENSURE_REQUIREMENTS, [plan_id=4793]
#
# (23) Sort
# Input [3]: [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L]
# Arguments: [Zip_Code#1328 ASC NULLS FIRST], false, 0
#
# (24) Scan geojson
# Output [1]: [features#1812]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (25) Filter
# Input [1]: [features#1812]
# Condition : ((size(features#1812, true) > 0) AND isnotnull(features#1812))
#
# (26) Generate
# Input [1]: [features#1812]
# Arguments: explode(features#1812), false, [features#1004]
#
# (27) Filter
# Input [1]: [features#1004]
# Condition : isnotnull(features#1004.properties.ZCTA10)
#
# (28) Project
# Output [2]: [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
# Input [1]: [features#1004]
#
# (29) HashAggregate
# Input [2]: [Zip_Code#1141, Population#1142L]
# Keys [1]: [Zip_Code#1141]
# Functions [1]: [partial_sum(Population#1142L)]
# Aggregate Attributes [1]: [sum#1157L]
# Results [2]: [Zip_Code#1141, sum#1158L]
#
# (30) Exchange
# Input [2]: [Zip_Code#1141, sum#1158L]
# Arguments: hashpartitioning(Zip_Code#1141, 1000), ENSURE_REQUIREMENTS, [plan_id=4745]
#
# (31) HashAggregate
# Input [2]: [Zip_Code#1141, sum#1158L]
# Keys [1]: [Zip_Code#1141]
# Functions [1]: [sum(Population#1142L)]
# Aggregate Attributes [1]: [sum(Population#1142L)#1147L]
# Results [2]: [Zip_Code#1141, sum(Population#1142L)#1147L AS Total_Population#1148L]
#
# (32) Sort
# Input [2]: [Zip_Code#1141, Total_Population#1148L]
# Arguments: [Zip_Code#1141 ASC NULLS FIRST], false, 0
#
# (33) SortMergeJoin
# Left keys [1]: [Zip_Code#1328]
# Right keys [1]: [Zip_Code#1141]
# Join type: Inner
# Join condition: None
#
# (34) Project
# Output [4]: [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
# Input [5]: [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Zip_Code#1141, Total_Population#1148L]
#
# (35) Scan csv
# Output [2]: [Zip Code#205, Estimated Median Income#207]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Zip Code)]
# ReadSchema: struct<Zip Code:int,Estimated Median Income:string>
#
# (36) Filter
# Input [2]: [Zip Code#205, Estimated Median Income#207]
# Condition : isnotnull(Zip Code#205)
#
# (37) Project
# Output [2]: [Zip Code#205 AS Zip_Code#421, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
# Input [2]: [Zip Code#205, Estimated Median Income#207]
#
# (38) BroadcastExchange
# Input [2]: [Zip_Code#421, Median_Income#1177]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=4755]
#
# (39) BroadcastHashJoin
# Left keys [1]: [cast(Zip_Code#1328 as int)]
# Right keys [1]: [Zip_Code#421]
# Join type: Inner
# Join condition: None
#
# (40) Project
# Output [4]: [AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Median_Income#1177]
# Input [6]: [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Zip_Code#421, Median_Income#1177]
#
# (41) HashAggregate
# Input [4]: [AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Median_Income#1177]
# Keys [1]: [AREA NAME#34]
# Functions [3]: [partial_sum(Median_Income#1177), partial_sum(Total_Population#1148L), partial_sum(Total_Crimes#1807L)]
# Aggregate Attributes [3]: [sum#1859, sum#1861L, sum#1863L]
# Results [4]: [AREA NAME#34, sum#1860, sum#1862L, sum#1864L]
#
# (42) Exchange
# Input [4]: [AREA NAME#34, sum#1860, sum#1862L, sum#1864L]
# Arguments: hashpartitioning(AREA NAME#34, 1000), ENSURE_REQUIREMENTS, [plan_id=4800]
#
# (43) HashAggregate
# Input [4]: [AREA NAME#34, sum#1860, sum#1862L, sum#1864L]
# Keys [1]: [AREA NAME#34]
# Functions [3]: [sum(Median_Income#1177), sum(Total_Population#1148L), sum(Total_Crimes#1807L)]
# Aggregate Attributes [3]: [sum(Median_Income#1177)#1834, sum(Total_Population#1148L)#1835L, sum(Total_Crimes#1807L)#1837L]
# Results [3]: [AREA NAME#34, (sum(Median_Income#1177)#1834 / cast(sum(Total_Population#1148L)#1835L as double)) AS Avg_Income_Per_Person#1836, (cast(sum(Total_Crimes#1807L)#1837L as double) / cast(sum(Total_Population#1148L)#1835L as double)) AS Crimes_Per_Person#1843]
#
# (44) AdaptiveSparkPlan
# Output [3]: [AREA NAME#34, Avg_Income_Per_Person#1836, Crimes_Per_Person#1843]
# Arguments: isFinalPlan=false

# %%
import time

start_time = time.time()

# Broadcast join
broadcast_join = zip_to_area_crime.hint("BROADCAST").join(
    population_data.hint("BROADCAST"),
    on="Zip_Code",
    how="inner"
).join(
    income_data.hint("BROADCAST"),
    on="Zip_Code",
    how="inner"
)

broadcast_join.show(5, truncate=False)
broadcast_join.explain(True)

# End timing
end_time = time.time()
elapsed_time_broadcast = end_time - start_time
print(f"Broadcast Join Time: {elapsed_time_broadcast:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------+----------+------------+----------------+-------------------------------------------------------------------------------------------------------+-------------+
# |Zip_Code|AREA NAME |Total_Crimes|Total_Population|Community                                                                                              |Median_Income|
# +--------+----------+------------+----------------+-------------------------------------------------------------------------------------------------------+-------------+
# |90723   |Hollenbeck|2           |54099           |Paramount                                                                                              |45792.0      |
# |90806   |Harbor    |1           |42399           |Long Beach                                                                                             |44144.0      |
# |91105   |Pacific   |4           |11254           |Pasadena                                                                                               |107209.0     |
# |90012   |Northeast |825         |31103           |Los Angeles (Downtown Civic Center, Chinatown, Arts District, Bunker Hill, Historic Core, Little Tokyo)|31576.0      |
# |90033   |Harbor    |1           |48852           |Los Angeles (Boyle Heights)                                                                            |27622.0      |
# +--------+----------+------------+----------------+-------------------------------------------------------------------------------------------------------+-------------+
# only showing top 5 rows
#
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner, [Zip_Code])
# :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
# :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141)
# :     :- ResolvedHint (strategy=broadcast)
# :     :  +- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
# :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
# :     :        :- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
# :     :        :  +- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
# :     :        :     +- Union false, false
# :     :        :        :- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
# :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
# :     :        +- Project [ZCTA10#1037 AS Zip_Code#1328, geometry#1313]
# :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
# :     :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
# :     :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
# :     :                    +- Project [features#1004]
# :     :                       +- Generate explode(features#996), false, [features#1004]
# :     :                          +- Relation [crs#995,features#996,name#997,type#998] geojson
# :     +- ResolvedHint (strategy=broadcast)
# :        +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
# :           +- Project [ZCTA10#1037 AS Zip_Code#1141, POP_2010#1029L AS Population#1142L]
# :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
# :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
# :                    +- Project [features#1004]
# :                       +- Generate explode(features#1956), false, [features#1004]
# :                          +- Relation [crs#1955,features#1956,name#1957,type#1958] geojson
# +- ResolvedHint (strategy=broadcast)
#    +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#762 as string), [$,], , 1) as double) AS Median_Income#1177]
#       +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#425 as string), [$,], , 1) as double) AS Median_Income#762]
#          +- Project [Zip_Code#421, Community#206, cast(regexp_replace(Median_Income#416, [$,], , 1) as double) AS Median_Income#425]
#             +- Project [Zip Code#205 AS Zip_Code#421, Community#206, Median_Income#416]
#                +- Project [Zip Code#205, Community#206, Estimated Median Income#207 AS Median_Income#416]
#                   +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Analyzed Logical Plan ==
# Zip_Code: string, AREA NAME: string, Total_Crimes: bigint, Total_Population: bigint, Community: string, Median_Income: double
# Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
# +- Join Inner, (cast(Zip_Code#1328 as int) = Zip_Code#421)
#    :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#    :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141)
#    :     :- ResolvedHint (strategy=broadcast)
#    :     :  +- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
#    :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :        :- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
#    :     :        :  +- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
#    :     :        :     +- Union false, false
#    :     :        :        :- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
#    :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
#    :     :        +- Project [ZCTA10#1037 AS Zip_Code#1328, geometry#1313]
#    :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
#    :     :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
#    :     :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
#    :     :                    +- Project [features#1004]
#    :     :                       +- Generate explode(features#996), false, [features#1004]
#    :     :                          +- Relation [crs#995,features#996,name#997,type#998] geojson
#    :     +- ResolvedHint (strategy=broadcast)
#    :        +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :           +- Project [ZCTA10#1037 AS Zip_Code#1141, POP_2010#1029L AS Population#1142L]
#    :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
#    :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
#    :                    +- Project [features#1004]
#    :                       +- Generate explode(features#1956), false, [features#1004]
#    :                          +- Relation [crs#1955,features#1956,name#1957,type#1958] geojson
#    +- ResolvedHint (strategy=broadcast)
#       +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#762 as string), [$,], , 1) as double) AS Median_Income#1177]
#          +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#425 as string), [$,], , 1) as double) AS Median_Income#762]
#             +- Project [Zip_Code#421, Community#206, cast(regexp_replace(Median_Income#416, [$,], , 1) as double) AS Median_Income#425]
#                +- Project [Zip Code#205 AS Zip_Code#421, Community#206, Median_Income#416]
#                   +- Project [Zip Code#205, Community#206, Estimated Median Income#207 AS Median_Income#416]
#                      +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Optimized Logical Plan ==
# Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
# +- Join Inner, (cast(Zip_Code#1328 as int) = Zip_Code#421), rightHint=(strategy=broadcast)
#    :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#    :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141), leftHint=(strategy=broadcast), rightHint=(strategy=broadcast)
#    :     :- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
#    :     :  +- Project [DR_NO#29, AREA NAME#34, Zip_Code#1328]
#    :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :        :- Union false, false
#    :     :        :  :- Project [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
#    :     :        :  :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :        :  :     +- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
#    :     :        :  +- Project [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#2035]
#    :     :        :     +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
#    :     :        +- Filter isnotnull(geometry#1313)
#    :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037 AS Zip_Code#1328, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
#    :     :              +- Project [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
#    :     :                 +- Filter isnotnull(features#1004.properties.ZCTA10)
#    :     :                    +- Generate explode(features#996), [0], false, [features#1004]
#    :     :                       +- Project [features#996]
#    :     :                          +- Filter ((size(features#996, true) > 0) AND isnotnull(features#996))
#    :     :                             +- Relation [crs#995,features#996,name#997,type#998] geojson
#    :     +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :        +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#    :           +- Filter isnotnull(features#1004.properties.ZCTA10)
#    :              +- Generate explode(features#1956), [0], false, [features#1004]
#    :                 +- Project [features#1956]
#    :                    +- Filter ((size(features#1956, true) > 0) AND isnotnull(features#1956))
#    :                       +- Relation [crs#1955,features#1956,name#1957,type#1958] geojson
#    +- Project [Zip Code#205 AS Zip_Code#421, Community#206, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
#       +- Filter isnotnull(Zip Code#205)
#          +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
#    +- BroadcastHashJoin [cast(Zip_Code#1328 as int)], [Zip_Code#421], Inner, BuildRight, false
#       :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#       :  +- BroadcastHashJoin [Zip_Code#1328], [Zip_Code#1141], Inner, BuildRight, false
#       :     :- HashAggregate(keys=[Zip_Code#1328, AREA NAME#34], functions=[count(DR_NO#29)], output=[Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L], schema specialized)
#       :     :  +- Exchange hashpartitioning(Zip_Code#1328, AREA NAME#34, 1000), ENSURE_REQUIREMENTS, [plan_id=5787]
#       :     :     +- HashAggregate(keys=[Zip_Code#1328, AREA NAME#34], functions=[partial_count(DR_NO#29)], output=[Zip_Code#1328, AREA NAME#34, count#1866L], schema specialized)
#       :     :        +- Project [DR_NO#29, AREA NAME#34, Zip_Code#1328]
#       :     :           +- RangeJoin geom#1253: geometry, geometry#1313: geometry, WITHIN
#       :     :              :- Union
#       :     :              :  :- Project [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
#       :     :              :  :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :     :              :  :     +- FileScan csv [DR_NO#29,AREA NAME#34,LAT#55,LON#56] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#       :     :              :  +- Project [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#2035]
#       :     :              :     +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :     :              :        +- FileScan csv [DR_NO#103,AREA NAME#108,LAT#129,LON#130] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#       :     :              +- Filter isnotnull(geometry#1313)
#       :     :                 +- ObjectHashAggregate(keys=[ZCTA10#1037], functions=[st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)], output=[Zip_Code#1328, geometry#1313])
#       :     :                    +- Exchange hashpartitioning(ZCTA10#1037, 1000), ENSURE_REQUIREMENTS, [plan_id=5780]
#       :     :                       +- ObjectHashAggregate(keys=[ZCTA10#1037], functions=[partial_st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)], output=[ZCTA10#1037, buf#1352])
#       :     :                          +- Project [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
#       :     :                             +- Filter isnotnull(features#1004.properties.ZCTA10)
#       :     :                                +- Generate explode(features#996), false, [features#1004]
#       :     :                                   +- Filter ((size(features#996, true) > 0) AND isnotnull(features#996))
#       :     :                                      +- FileScan geojson [features#996] Batched: false, DataFilters: [(size(features#996, true) > 0), isnotnull(features#996)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       :     +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=5792]
#       :        +- HashAggregate(keys=[Zip_Code#1141], functions=[sum(Population#1142L)], output=[Zip_Code#1141, Total_Population#1148L], schema specialized)
#       :           +- Exchange hashpartitioning(Zip_Code#1141, 1000), ENSURE_REQUIREMENTS, [plan_id=5789]
#       :              +- HashAggregate(keys=[Zip_Code#1141], functions=[partial_sum(Population#1142L)], output=[Zip_Code#1141, sum#1158L], schema specialized)
#       :                 +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#       :                    +- Filter isnotnull(features#1004.properties.ZCTA10)
#       :                       +- Generate explode(features#1956), false, [features#1004]
#       :                          +- Filter ((size(features#1956, true) > 0) AND isnotnull(features#1956))
#       :                             +- FileScan geojson [features#1956] Batched: false, DataFilters: [(size(features#1956, true) > 0), isnotnull(features#1956)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=5796]
#          +- Project [Zip Code#205 AS Zip_Code#421, Community#206, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
#             +- Filter isnotnull(Zip Code#205)
#                +- FileScan csv [Zip Code#205,Community#206,Estimated Median Income#207] Batched: false, DataFilters: [isnotnull(Zip Code#205)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Community:string,Estimated Median Income:string>
#
# Broadcast Join Time: 635.54 seconds

# %%
import time

start_time = time.time()

# Merge join
merge_join = zip_to_area_crime.hint("MERGE").join(
    population_data.hint("MERGE"),
    on="Zip_Code",
    how="inner"
).join(
    income_data.hint("MERGE"),
    on="Zip_Code",
    how="inner"
)

merge_join.show(5, truncate=False)
merge_join.explain(True)

# End timing
end_time = time.time()
elapsed_time_merge = end_time - start_time
print(f"Merge Join Time: {elapsed_time_merge:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------+-----------+------------+----------------+------------------------------------------------+-------------+
# |Zip_Code|AREA NAME  |Total_Crimes|Total_Population|Community                                       |Median_Income|
# +--------+-----------+------------+----------------+------------------------------------------------+-------------+
# |90001   |77th Street|9872        |57110           |Los Angeles (South Los Angeles), Florence-Graham|33887.0      |
# |90001   |Southwest  |2           |57110           |Los Angeles (South Los Angeles), Florence-Graham|33887.0      |
# |90001   |Harbor     |1           |57110           |Los Angeles (South Los Angeles), Florence-Graham|33887.0      |
# |90001   |Newton     |1759        |57110           |Los Angeles (South Los Angeles), Florence-Graham|33887.0      |
# |90001   |Southeast  |882         |57110           |Los Angeles (South Los Angeles), Florence-Graham|33887.0      |
# +--------+-----------+------------+----------------+------------------------------------------------+-------------+
# only showing top 5 rows
#
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner, [Zip_Code])
# :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
# :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141)
# :     :- ResolvedHint (strategy=merge)
# :     :  +- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
# :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
# :     :        :- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
# :     :        :  +- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
# :     :        :     +- Union false, false
# :     :        :        :- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
# :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
# :     :        +- Project [ZCTA10#1037 AS Zip_Code#1328, geometry#1313]
# :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
# :     :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
# :     :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
# :     :                    +- Project [features#1004]
# :     :                       +- Generate explode(features#996), false, [features#1004]
# :     :                          +- Relation [crs#995,features#996,name#997,type#998] geojson
# :     +- ResolvedHint (strategy=merge)
# :        +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
# :           +- Project [ZCTA10#1037 AS Zip_Code#1141, POP_2010#1029L AS Population#1142L]
# :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
# :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
# :                    +- Project [features#1004]
# :                       +- Generate explode(features#2046), false, [features#1004]
# :                          +- Relation [crs#2045,features#2046,name#2047,type#2048] geojson
# +- ResolvedHint (strategy=merge)
#    +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#762 as string), [$,], , 1) as double) AS Median_Income#1177]
#       +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#425 as string), [$,], , 1) as double) AS Median_Income#762]
#          +- Project [Zip_Code#421, Community#206, cast(regexp_replace(Median_Income#416, [$,], , 1) as double) AS Median_Income#425]
#             +- Project [Zip Code#205 AS Zip_Code#421, Community#206, Median_Income#416]
#                +- Project [Zip Code#205, Community#206, Estimated Median Income#207 AS Median_Income#416]
#                   +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Analyzed Logical Plan ==
# Zip_Code: string, AREA NAME: string, Total_Crimes: bigint, Total_Population: bigint, Community: string, Median_Income: double
# Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
# +- Join Inner, (cast(Zip_Code#1328 as int) = Zip_Code#421)
#    :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#    :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141)
#    :     :- ResolvedHint (strategy=merge)
#    :     :  +- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
#    :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :        :- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
#    :     :        :  +- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
#    :     :        :     +- Union false, false
#    :     :        :        :- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
#    :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
#    :     :        +- Project [ZCTA10#1037 AS Zip_Code#1328, geometry#1313]
#    :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
#    :     :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
#    :     :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
#    :     :                    +- Project [features#1004]
#    :     :                       +- Generate explode(features#996), false, [features#1004]
#    :     :                          +- Relation [crs#995,features#996,name#997,type#998] geojson
#    :     +- ResolvedHint (strategy=merge)
#    :        +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :           +- Project [ZCTA10#1037 AS Zip_Code#1141, POP_2010#1029L AS Population#1142L]
#    :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
#    :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
#    :                    +- Project [features#1004]
#    :                       +- Generate explode(features#2046), false, [features#1004]
#    :                          +- Relation [crs#2045,features#2046,name#2047,type#2048] geojson
#    +- ResolvedHint (strategy=merge)
#       +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#762 as string), [$,], , 1) as double) AS Median_Income#1177]
#          +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#425 as string), [$,], , 1) as double) AS Median_Income#762]
#             +- Project [Zip_Code#421, Community#206, cast(regexp_replace(Median_Income#416, [$,], , 1) as double) AS Median_Income#425]
#                +- Project [Zip Code#205 AS Zip_Code#421, Community#206, Median_Income#416]
#                   +- Project [Zip Code#205, Community#206, Estimated Median Income#207 AS Median_Income#416]
#                      +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Optimized Logical Plan ==
# Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
# +- Join Inner, (cast(Zip_Code#1328 as int) = Zip_Code#421), rightHint=(strategy=merge)
#    :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#    :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141), leftHint=(strategy=merge), rightHint=(strategy=merge)
#    :     :- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
#    :     :  +- Project [DR_NO#29, AREA NAME#34, Zip_Code#1328]
#    :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :        :- Union false, false
#    :     :        :  :- Project [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
#    :     :        :  :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :        :  :     +- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
#    :     :        :  +- Project [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#2126]
#    :     :        :     +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
#    :     :        +- Filter isnotnull(geometry#1313)
#    :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037 AS Zip_Code#1328, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
#    :     :              +- Project [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
#    :     :                 +- Filter (isnotnull(features#1004.properties.ZCTA10) AND bloomfilter#2127 of [Zip_Code#1141] filtering [features#1004.properties.ZCTA10])
#    :     :                    :  +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :     :                    :     +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#    :     :                    :        +- Filter isnotnull(features#1004.properties.ZCTA10)
#    :     :                    :           +- Generate explode(features#2046), [0], false, [features#1004]
#    :     :                    :              +- Project [features#2046]
#    :     :                    :                 +- Filter ((size(features#2046, true) > 0) AND isnotnull(features#2046))
#    :     :                    :                    +- Relation [crs#2045,features#2046,name#2047,type#2048] geojson
#    :     :                    +- Generate explode(features#996), [0], false, [features#1004]
#    :     :                       +- Project [features#996]
#    :     :                          +- Filter ((size(features#996, true) > 0) AND isnotnull(features#996))
#    :     :                             +- Relation [crs#995,features#996,name#997,type#998] geojson
#    :     +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :        +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#    :           +- Filter isnotnull(features#1004.properties.ZCTA10)
#    :              +- Generate explode(features#2046), [0], false, [features#1004]
#    :                 +- Project [features#2046]
#    :                    +- Filter ((size(features#2046, true) > 0) AND isnotnull(features#2046))
#    :                       +- Relation [crs#2045,features#2046,name#2047,type#2048] geojson
#    +- Project [Zip Code#205 AS Zip_Code#421, Community#206, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
#       +- Filter isnotnull(Zip Code#205)
#          +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
#    +- SortMergeJoin [cast(Zip_Code#1328 as int)], [Zip_Code#421], Inner
#       :- Sort [cast(Zip_Code#1328 as int) ASC NULLS FIRST], false, 0
#       :  +- Exchange hashpartitioning(cast(Zip_Code#1328 as int), 1000), ENSURE_REQUIREMENTS, [plan_id=7141]
#       :     +- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#       :        +- SortMergeJoin [Zip_Code#1328], [Zip_Code#1141], Inner
#       :           :- Sort [Zip_Code#1328 ASC NULLS FIRST], false, 0
#       :           :  +- Exchange hashpartitioning(Zip_Code#1328, 1000), ENSURE_REQUIREMENTS, [plan_id=7137]
#       :           :     +- HashAggregate(keys=[Zip_Code#1328, AREA NAME#34], functions=[count(DR_NO#29)], output=[Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L], schema specialized)
#       :           :        +- Exchange hashpartitioning(Zip_Code#1328, AREA NAME#34, 1000), ENSURE_REQUIREMENTS, [plan_id=7135]
#       :           :           +- HashAggregate(keys=[Zip_Code#1328, AREA NAME#34], functions=[partial_count(DR_NO#29)], output=[Zip_Code#1328, AREA NAME#34, count#1866L], schema specialized)
#       :           :              +- Project [DR_NO#29, AREA NAME#34, Zip_Code#1328]
#       :           :                 +- RangeJoin geom#1253: geometry, geometry#1313: geometry, WITHIN
#       :           :                    :- Union
#       :           :                    :  :- Project [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
#       :           :                    :  :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :           :                    :  :     +- FileScan csv [DR_NO#29,AREA NAME#34,LAT#55,LON#56] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#       :           :                    :  +- Project [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#2126]
#       :           :                    :     +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :           :                    :        +- FileScan csv [DR_NO#103,AREA NAME#108,LAT#129,LON#130] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#       :           :                    +- Filter isnotnull(geometry#1313)
#       :           :                       +- ObjectHashAggregate(keys=[ZCTA10#1037], functions=[st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)], output=[Zip_Code#1328, geometry#1313])
#       :           :                          +- Exchange hashpartitioning(ZCTA10#1037, 1000), ENSURE_REQUIREMENTS, [plan_id=7129]
#       :           :                             +- ObjectHashAggregate(keys=[ZCTA10#1037], functions=[partial_st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)], output=[ZCTA10#1037, buf#1352])
#       :           :                                +- Project [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
#       :           :                                   +- Filter isnotnull(features#1004.properties.ZCTA10)
#       :           :                                      +- Generate explode(features#996), false, [features#1004]
#       :           :                                         +- Filter ((size(features#996, true) > 0) AND isnotnull(features#996))
#       :           :                                            +- FileScan geojson [features#996] Batched: false, DataFilters: [(size(features#996, true) > 0), isnotnull(features#996)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       :           +- Sort [Zip_Code#1141 ASC NULLS FIRST], false, 0
#       :              +- HashAggregate(keys=[Zip_Code#1141], functions=[sum(Population#1142L)], output=[Zip_Code#1141, Total_Population#1148L], schema specialized)
#       :                 +- Exchange hashpartitioning(Zip_Code#1141, 1000), ENSURE_REQUIREMENTS, [plan_id=7090]
#       :                    +- HashAggregate(keys=[Zip_Code#1141], functions=[partial_sum(Population#1142L)], output=[Zip_Code#1141, sum#1158L], schema specialized)
#       :                       +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#       :                          +- Filter isnotnull(features#1004.properties.ZCTA10)
#       :                             +- Generate explode(features#2046), false, [features#1004]
#       :                                +- Filter ((size(features#2046, true) > 0) AND isnotnull(features#2046))
#       :                                   +- FileScan geojson [features#2046] Batched: false, DataFilters: [(size(features#2046, true) > 0), isnotnull(features#2046)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       +- Sort [Zip_Code#421 ASC NULLS FIRST], false, 0
#          +- Exchange hashpartitioning(Zip_Code#421, 1000), ENSURE_REQUIREMENTS, [plan_id=7102]
#             +- Project [Zip Code#205 AS Zip_Code#421, Community#206, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
#                +- Filter isnotnull(Zip Code#205)
#                   +- FileScan csv [Zip Code#205,Community#206,Estimated Median Income#207] Batched: false, DataFilters: [isnotnull(Zip Code#205)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Community:string,Estimated Median Income:string>
#
# Merge Join Time: 433.70 seconds

# %%
import time

start_time = time.time()

# Shuffle hash join
shuffle_hash_join = zip_to_area_crime.hint("SHUFFLE_HASH").join(
    population_data.hint("SHUFFLE_HASH"),
    on="Zip_Code",
    how="inner"
).join(
    income_data.hint("SHUFFLE_HASH"),
    on="Zip_Code",
    how="inner"
)

shuffle_hash_join.show(5, truncate=False)
shuffle_hash_join.explain(True)

# End timing
end_time = time.time()
elapsed_time_shuffle_hash = end_time - start_time
print(f"Shuffle Hash Join Time: {elapsed_time_shuffle_hash:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------+---------+------------+----------------+------------------------------------------------+-------------+
# |Zip_Code|AREA NAME|Total_Crimes|Total_Population|Community                                       |Median_Income|
# +--------+---------+------------+----------------+------------------------------------------------+-------------+
# |90069   |Hollywood|2371        |20483           |Los Angeles (Hollywood, Melrose), West Hollywood|78979.0      |
# |90069   |Olympic  |2           |20483           |Los Angeles (Hollywood, Melrose), West Hollywood|78979.0      |
# |90069   |Wilshire |2356        |20483           |Los Angeles (Hollywood, Melrose), West Hollywood|78979.0      |
# |90094   |Pacific  |3599        |5464            |Los Angeles (Playa Vista)                       |104367.0     |
# |90304   |Pacific  |129         |28210           |Inglewood, Lennox                               |36412.0      |
# +--------+---------+------------+----------------+------------------------------------------------+-------------+
# only showing top 5 rows
#
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner, [Zip_Code])
# :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
# :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141)
# :     :- ResolvedHint (strategy=shuffle_hash)
# :     :  +- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
# :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
# :     :        :- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
# :     :        :  +- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
# :     :        :     +- Union false, false
# :     :        :        :- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
# :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
# :     :        +- Project [ZCTA10#1037 AS Zip_Code#1328, geometry#1313]
# :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
# :     :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
# :     :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
# :     :                    +- Project [features#1004]
# :     :                       +- Generate explode(features#996), false, [features#1004]
# :     :                          +- Relation [crs#995,features#996,name#997,type#998] geojson
# :     +- ResolvedHint (strategy=shuffle_hash)
# :        +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
# :           +- Project [ZCTA10#1037 AS Zip_Code#1141, POP_2010#1029L AS Population#1142L]
# :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
# :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
# :                    +- Project [features#1004]
# :                       +- Generate explode(features#2138), false, [features#1004]
# :                          +- Relation [crs#2137,features#2138,name#2139,type#2140] geojson
# +- ResolvedHint (strategy=shuffle_hash)
#    +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#762 as string), [$,], , 1) as double) AS Median_Income#1177]
#       +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#425 as string), [$,], , 1) as double) AS Median_Income#762]
#          +- Project [Zip_Code#421, Community#206, cast(regexp_replace(Median_Income#416, [$,], , 1) as double) AS Median_Income#425]
#             +- Project [Zip Code#205 AS Zip_Code#421, Community#206, Median_Income#416]
#                +- Project [Zip Code#205, Community#206, Estimated Median Income#207 AS Median_Income#416]
#                   +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Analyzed Logical Plan ==
# Zip_Code: string, AREA NAME: string, Total_Crimes: bigint, Total_Population: bigint, Community: string, Median_Income: double
# Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
# +- Join Inner, (cast(Zip_Code#1328 as int) = Zip_Code#421)
#    :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#    :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141)
#    :     :- ResolvedHint (strategy=shuffle_hash)
#    :     :  +- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
#    :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :        :- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
#    :     :        :  +- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
#    :     :        :     +- Union false, false
#    :     :        :        :- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
#    :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
#    :     :        +- Project [ZCTA10#1037 AS Zip_Code#1328, geometry#1313]
#    :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
#    :     :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
#    :     :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
#    :     :                    +- Project [features#1004]
#    :     :                       +- Generate explode(features#996), false, [features#1004]
#    :     :                          +- Relation [crs#995,features#996,name#997,type#998] geojson
#    :     +- ResolvedHint (strategy=shuffle_hash)
#    :        +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :           +- Project [ZCTA10#1037 AS Zip_Code#1141, POP_2010#1029L AS Population#1142L]
#    :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
#    :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
#    :                    +- Project [features#1004]
#    :                       +- Generate explode(features#2138), false, [features#1004]
#    :                          +- Relation [crs#2137,features#2138,name#2139,type#2140] geojson
#    +- ResolvedHint (strategy=shuffle_hash)
#       +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#762 as string), [$,], , 1) as double) AS Median_Income#1177]
#          +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#425 as string), [$,], , 1) as double) AS Median_Income#762]
#             +- Project [Zip_Code#421, Community#206, cast(regexp_replace(Median_Income#416, [$,], , 1) as double) AS Median_Income#425]
#                +- Project [Zip Code#205 AS Zip_Code#421, Community#206, Median_Income#416]
#                   +- Project [Zip Code#205, Community#206, Estimated Median Income#207 AS Median_Income#416]
#                      +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Optimized Logical Plan ==
# Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
# +- Join Inner, (cast(Zip_Code#1328 as int) = Zip_Code#421), rightHint=(strategy=shuffle_hash)
#    :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#    :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141), leftHint=(strategy=shuffle_hash), rightHint=(strategy=shuffle_hash)
#    :     :- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
#    :     :  +- Project [DR_NO#29, AREA NAME#34, Zip_Code#1328]
#    :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :        :- Union false, false
#    :     :        :  :- Project [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
#    :     :        :  :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :        :  :     +- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
#    :     :        :  +- Project [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#2218]
#    :     :        :     +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
#    :     :        +- Filter isnotnull(geometry#1313)
#    :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037 AS Zip_Code#1328, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
#    :     :              +- Project [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
#    :     :                 +- Filter (isnotnull(features#1004.properties.ZCTA10) AND bloomfilter#2219 of [Zip_Code#1141] filtering [features#1004.properties.ZCTA10])
#    :     :                    :  +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :     :                    :     +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#    :     :                    :        +- Filter isnotnull(features#1004.properties.ZCTA10)
#    :     :                    :           +- Generate explode(features#2138), [0], false, [features#1004]
#    :     :                    :              +- Project [features#2138]
#    :     :                    :                 +- Filter ((size(features#2138, true) > 0) AND isnotnull(features#2138))
#    :     :                    :                    +- Relation [crs#2137,features#2138,name#2139,type#2140] geojson
#    :     :                    +- Generate explode(features#996), [0], false, [features#1004]
#    :     :                       +- Project [features#996]
#    :     :                          +- Filter ((size(features#996, true) > 0) AND isnotnull(features#996))
#    :     :                             +- Relation [crs#995,features#996,name#997,type#998] geojson
#    :     +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :        +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#    :           +- Filter isnotnull(features#1004.properties.ZCTA10)
#    :              +- Generate explode(features#2138), [0], false, [features#1004]
#    :                 +- Project [features#2138]
#    :                    +- Filter ((size(features#2138, true) > 0) AND isnotnull(features#2138))
#    :                       +- Relation [crs#2137,features#2138,name#2139,type#2140] geojson
#    +- Project [Zip Code#205 AS Zip_Code#421, Community#206, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
#       +- Filter isnotnull(Zip Code#205)
#          +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
#    +- ShuffledHashJoin [cast(Zip_Code#1328 as int)], [Zip_Code#421], Inner, BuildRight
#       :- Exchange hashpartitioning(cast(Zip_Code#1328 as int), 1000), ENSURE_REQUIREMENTS, [plan_id=8404]
#       :  +- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#       :     +- ShuffledHashJoin [Zip_Code#1328], [Zip_Code#1141], Inner, BuildRight
#       :        :- Exchange hashpartitioning(Zip_Code#1328, 1000), ENSURE_REQUIREMENTS, [plan_id=8401]
#       :        :  +- HashAggregate(keys=[Zip_Code#1328, AREA NAME#34], functions=[count(DR_NO#29)], output=[Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L], schema specialized)
#       :        :     +- Exchange hashpartitioning(Zip_Code#1328, AREA NAME#34, 1000), ENSURE_REQUIREMENTS, [plan_id=8399]
#       :        :        +- HashAggregate(keys=[Zip_Code#1328, AREA NAME#34], functions=[partial_count(DR_NO#29)], output=[Zip_Code#1328, AREA NAME#34, count#1866L], schema specialized)
#       :        :           +- Project [DR_NO#29, AREA NAME#34, Zip_Code#1328]
#       :        :              +- RangeJoin geom#1253: geometry, geometry#1313: geometry, WITHIN
#       :        :                 :- Union
#       :        :                 :  :- Project [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
#       :        :                 :  :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :        :                 :  :     +- FileScan csv [DR_NO#29,AREA NAME#34,LAT#55,LON#56] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#       :        :                 :  +- Project [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#2218]
#       :        :                 :     +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :        :                 :        +- FileScan csv [DR_NO#103,AREA NAME#108,LAT#129,LON#130] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#       :        :                 +- Filter isnotnull(geometry#1313)
#       :        :                    +- ObjectHashAggregate(keys=[ZCTA10#1037], functions=[st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)], output=[Zip_Code#1328, geometry#1313])
#       :        :                       +- Exchange hashpartitioning(ZCTA10#1037, 1000), ENSURE_REQUIREMENTS, [plan_id=8393]
#       :        :                          +- ObjectHashAggregate(keys=[ZCTA10#1037], functions=[partial_st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)], output=[ZCTA10#1037, buf#1352])
#       :        :                             +- Project [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
#       :        :                                +- Filter isnotnull(features#1004.properties.ZCTA10)
#       :        :                                   +- Generate explode(features#996), false, [features#1004]
#       :        :                                      +- Filter ((size(features#996, true) > 0) AND isnotnull(features#996))
#       :        :                                         +- FileScan geojson [features#996] Batched: false, DataFilters: [(size(features#996, true) > 0), isnotnull(features#996)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       :        +- HashAggregate(keys=[Zip_Code#1141], functions=[sum(Population#1142L)], output=[Zip_Code#1141, Total_Population#1148L], schema specialized)
#       :           +- Exchange hashpartitioning(Zip_Code#1141, 1000), ENSURE_REQUIREMENTS, [plan_id=8360]
#       :              +- HashAggregate(keys=[Zip_Code#1141], functions=[partial_sum(Population#1142L)], output=[Zip_Code#1141, sum#1158L], schema specialized)
#       :                 +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#       :                    +- Filter isnotnull(features#1004.properties.ZCTA10)
#       :                       +- Generate explode(features#2138), false, [features#1004]
#       :                          +- Filter ((size(features#2138, true) > 0) AND isnotnull(features#2138))
#       :                             +- FileScan geojson [features#2138] Batched: false, DataFilters: [(size(features#2138, true) > 0), isnotnull(features#2138)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       +- Exchange hashpartitioning(Zip_Code#421, 1000), ENSURE_REQUIREMENTS, [plan_id=8370]
#          +- Project [Zip Code#205 AS Zip_Code#421, Community#206, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
#             +- Filter isnotnull(Zip Code#205)
#                +- FileScan csv [Zip Code#205,Community#206,Estimated Median Income#207] Batched: false, DataFilters: [isnotnull(Zip Code#205)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Community:string,Estimated Median Income:string>
#
# Shuffle Hash Join Time: 565.34 seconds

# %%
import time

start_time = time.time()

# Shuffle replicate nested loop join
shuffle_replicate_join = zip_to_area_crime.hint("SHUFFLE_REPLICATE_NL").join(
    population_data.hint("SHUFFLE_REPLICATE_NL"),
    on="Zip_Code",
    how="inner"
).join(
    income_data.hint("SHUFFLE_REPLICATE_NL"),
    on="Zip_Code",
    how="inner"
)

shuffle_replicate_join.show(5, truncate=False)
shuffle_replicate_join.explain(True)

# End timing
end_time = time.time()
elapsed_time_shuffle_replicate = end_time - start_time
print(f"Shuffle Replicate NL Join Time: {elapsed_time_shuffle_replicate:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------+-----------+------------+----------------+----------------------------------------------------------------+-------------+
# |Zip_Code|AREA NAME  |Total_Crimes|Total_Population|Community                                                       |Median_Income|
# +--------+-----------+------------+----------------+----------------------------------------------------------------+-------------+
# |90003   |77th Street|29994       |66266           |Los Angeles (South Los Angeles, Southeast Los Angeles)          |30805.0      |
# |90044   |Southeast  |24003       |89779           |Athens, Los Angeles (South Los Angeles)                         |29206.0      |
# |90275   |Hollenbeck |1           |41804           |Palos Verdes Estates, Rancho Palos Verdes, Rolling Hills Estates|118790.0     |
# |90044   |77th Street|51293       |89779           |Athens, Los Angeles (South Los Angeles)                         |29206.0      |
# |90044   |Newton     |2           |89779           |Athens, Los Angeles (South Los Angeles)                         |29206.0      |
# +--------+-----------+------------+----------------+----------------------------------------------------------------+-------------+
# only showing top 5 rows
#
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner, [Zip_Code])
# :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
# :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141)
# :     :- ResolvedHint (strategy=shuffle_replicate_nl)
# :     :  +- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
# :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
# :     :        :- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
# :     :        :  +- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
# :     :        :     +- Union false, false
# :     :        :        :- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
# :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
# :     :        +- Project [ZCTA10#1037 AS Zip_Code#1328, geometry#1313]
# :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
# :     :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
# :     :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
# :     :                    +- Project [features#1004]
# :     :                       +- Generate explode(features#996), false, [features#1004]
# :     :                          +- Relation [crs#995,features#996,name#997,type#998] geojson
# :     +- ResolvedHint (strategy=shuffle_replicate_nl)
# :        +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
# :           +- Project [ZCTA10#1037 AS Zip_Code#1141, POP_2010#1029L AS Population#1142L]
# :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
# :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
# :                    +- Project [features#1004]
# :                       +- Generate explode(features#2230), false, [features#1004]
# :                          +- Relation [crs#2229,features#2230,name#2231,type#2232] geojson
# +- ResolvedHint (strategy=shuffle_replicate_nl)
#    +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#762 as string), [$,], , 1) as double) AS Median_Income#1177]
#       +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#425 as string), [$,], , 1) as double) AS Median_Income#762]
#          +- Project [Zip_Code#421, Community#206, cast(regexp_replace(Median_Income#416, [$,], , 1) as double) AS Median_Income#425]
#             +- Project [Zip Code#205 AS Zip_Code#421, Community#206, Median_Income#416]
#                +- Project [Zip Code#205, Community#206, Estimated Median Income#207 AS Median_Income#416]
#                   +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Analyzed Logical Plan ==
# Zip_Code: string, AREA NAME: string, Total_Crimes: bigint, Total_Population: bigint, Community: string, Median_Income: double
# Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
# +- Join Inner, (cast(Zip_Code#1328 as int) = Zip_Code#421)
#    :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#    :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141)
#    :     :- ResolvedHint (strategy=shuffle_replicate_nl)
#    :     :  +- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
#    :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :        :- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
#    :     :        :  +- Project [DR_NO#29, Date Rptd#30, DATE OCC#31, TIME OCC#32, AREA #33, AREA NAME#34, Rpt Dist No#35, Part 1-2#36, Crm Cd#37, Crm Cd Desc#38, Mocodes#39, Vict Age#40, Vict Sex#41, Vict Descent#42, Premis Cd#43, Premis Desc#44, Weapon Used Cd#45, Weapon Desc#46, Status#47, Status Desc#48, Crm Cd 1#49, Crm Cd 2#50, Crm Cd 3#51, Crm Cd 4#52, ... 5 more fields]
#    :     :        :     +- Union false, false
#    :     :        :        :- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
#    :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
#    :     :        +- Project [ZCTA10#1037 AS Zip_Code#1328, geometry#1313]
#    :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
#    :     :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
#    :     :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
#    :     :                    +- Project [features#1004]
#    :     :                       +- Generate explode(features#996), false, [features#1004]
#    :     :                          +- Relation [crs#995,features#996,name#997,type#998] geojson
#    :     +- ResolvedHint (strategy=shuffle_replicate_nl)
#    :        +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :           +- Project [ZCTA10#1037 AS Zip_Code#1141, POP_2010#1029L AS Population#1142L]
#    :              +- Project [properties#1008.BG10 AS BG10#1013, properties#1008.BG10FIP10 AS BG10FIP10#1014, properties#1008.BG12 AS BG12#1015, properties#1008.CB10 AS CB10#1016, properties#1008.CEN_FIP13 AS CEN_FIP13#1017, properties#1008.CITY AS CITY#1018, properties#1008.CITYCOM AS CITYCOM#1019, properties#1008.COMM AS COMM#1020, properties#1008.CT10 AS CT10#1021, properties#1008.CT12 AS CT12#1022, properties#1008.CTCB10 AS CTCB10#1023, properties#1008.HD_2012 AS HD_2012#1024L, properties#1008.HD_NAME AS HD_NAME#1025, properties#1008.HOUSING10 AS HOUSING10#1026L, properties#1008.LA_FIP10 AS LA_FIP10#1027, properties#1008.OBJECTID AS OBJECTID#1028L, properties#1008.POP_2010 AS POP_2010#1029L, properties#1008.PUMA10 AS PUMA10#1030, properties#1008.SPA_2012 AS SPA_2012#1031L, properties#1008.SPA_NAME AS SPA_NAME#1032, properties#1008.SUP_DIST AS SUP_DIST#1033, properties#1008.SUP_LABEL AS SUP_LABEL#1034, properties#1008.ShapeSTArea AS ShapeSTArea#1035, properties#1008.ShapeSTLength AS ShapeSTLength#1036, ... 2 more fields]
#    :                 +- Project [features#1004.geometry AS geometry#1007, features#1004.properties AS properties#1008, features#1004.type AS type#1009]
#    :                    +- Project [features#1004]
#    :                       +- Generate explode(features#2230), false, [features#1004]
#    :                          +- Relation [crs#2229,features#2230,name#2231,type#2232] geojson
#    +- ResolvedHint (strategy=shuffle_replicate_nl)
#       +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#762 as string), [$,], , 1) as double) AS Median_Income#1177]
#          +- Project [Zip_Code#421, Community#206, cast(regexp_replace(cast(Median_Income#425 as string), [$,], , 1) as double) AS Median_Income#762]
#             +- Project [Zip_Code#421, Community#206, cast(regexp_replace(Median_Income#416, [$,], , 1) as double) AS Median_Income#425]
#                +- Project [Zip Code#205 AS Zip_Code#421, Community#206, Median_Income#416]
#                   +- Project [Zip Code#205, Community#206, Estimated Median Income#207 AS Median_Income#416]
#                      +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Optimized Logical Plan ==
# Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
# +- Join Inner, (cast(Zip_Code#1328 as int) = Zip_Code#421), rightHint=(strategy=shuffle_replicate_nl)
#    :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#    :  +- Join Inner, (Zip_Code#1328 = Zip_Code#1141), leftHint=(strategy=shuffle_replicate_nl), rightHint=(strategy=shuffle_replicate_nl)
#    :     :- Aggregate [Zip_Code#1328, AREA NAME#34], [Zip_Code#1328, AREA NAME#34, count(DR_NO#29) AS Total_Crimes#1807L]
#    :     :  +- Project [DR_NO#29, AREA NAME#34, Zip_Code#1328]
#    :     :     +- Join Inner,  **org.apache.spark.sql.sedona_sql.expressions.ST_Within**
#    :     :        :- Union false, false
#    :     :        :  :- Project [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
#    :     :        :  :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :        :  :     +- Relation [DR_NO#29,Date Rptd#30,DATE OCC#31,TIME OCC#32,AREA #33,AREA NAME#34,Rpt Dist No#35,Part 1-2#36,Crm Cd#37,Crm Cd Desc#38,Mocodes#39,Vict Age#40,Vict Sex#41,Vict Descent#42,Premis Cd#43,Premis Desc#44,Weapon Used Cd#45,Weapon Desc#46,Status#47,Status Desc#48,Crm Cd 1#49,Crm Cd 2#50,Crm Cd 3#51,Crm Cd 4#52,... 4 more fields] csv
#    :     :        :  +- Project [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#2310]
#    :     :        :     +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#    :     :        :        +- Relation [DR_NO#103,Date Rptd#104,DATE OCC#105,TIME OCC#106,AREA#107,AREA NAME#108,Rpt Dist No#109,Part 1-2#110,Crm Cd#111,Crm Cd Desc#112,Mocodes#113,Vict Age#114,Vict Sex#115,Vict Descent#116,Premis Cd#117,Premis Desc#118,Weapon Used Cd#119,Weapon Desc#120,Status#121,Status Desc#122,Crm Cd 1#123,Crm Cd 2#124,Crm Cd 3#125,Crm Cd 4#126,... 4 more fields] csv
#    :     :        +- Filter isnotnull(geometry#1313)
#    :     :           +- Aggregate [ZCTA10#1037], [ZCTA10#1037 AS Zip_Code#1328, st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None) AS geometry#1313]
#    :     :              +- Project [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
#    :     :                 +- Filter (isnotnull(features#1004.properties.ZCTA10) AND bloomfilter#2311 of [Zip_Code#1141] filtering [features#1004.properties.ZCTA10])
#    :     :                    :  +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :     :                    :     +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#    :     :                    :        +- Filter isnotnull(features#1004.properties.ZCTA10)
#    :     :                    :           +- Generate explode(features#2230), [0], false, [features#1004]
#    :     :                    :              +- Project [features#2230]
#    :     :                    :                 +- Filter ((size(features#2230, true) > 0) AND isnotnull(features#2230))
#    :     :                    :                    +- Relation [crs#2229,features#2230,name#2231,type#2232] geojson
#    :     :                    +- Generate explode(features#996), [0], false, [features#1004]
#    :     :                       +- Project [features#996]
#    :     :                          +- Filter ((size(features#996, true) > 0) AND isnotnull(features#996))
#    :     :                             +- Relation [crs#995,features#996,name#997,type#998] geojson
#    :     +- Aggregate [Zip_Code#1141], [Zip_Code#1141, sum(Population#1142L) AS Total_Population#1148L]
#    :        +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#    :           +- Filter isnotnull(features#1004.properties.ZCTA10)
#    :              +- Generate explode(features#2230), [0], false, [features#1004]
#    :                 +- Project [features#2230]
#    :                    +- Filter ((size(features#2230, true) > 0) AND isnotnull(features#2230))
#    :                       +- Relation [crs#2229,features#2230,name#2231,type#2232] geojson
#    +- Project [Zip Code#205 AS Zip_Code#421, Community#206, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
#       +- Filter isnotnull(Zip Code#205)
#          +- Relation [Zip Code#205,Community#206,Estimated Median Income#207] csv
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L, Community#206, Median_Income#1177]
#    +- CartesianProduct (cast(Zip_Code#1328 as int) = Zip_Code#421)
#       :- Project [Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L, Total_Population#1148L]
#       :  +- CartesianProduct (Zip_Code#1328 = Zip_Code#1141)
#       :     :- HashAggregate(keys=[Zip_Code#1328, AREA NAME#34], functions=[count(DR_NO#29)], output=[Zip_Code#1328, AREA NAME#34, Total_Crimes#1807L], schema specialized)
#       :     :  +- Exchange hashpartitioning(Zip_Code#1328, AREA NAME#34, 1000), ENSURE_REQUIREMENTS, [plan_id=9380]
#       :     :     +- HashAggregate(keys=[Zip_Code#1328, AREA NAME#34], functions=[partial_count(DR_NO#29)], output=[Zip_Code#1328, AREA NAME#34, count#1866L], schema specialized)
#       :     :        +- Project [DR_NO#29, AREA NAME#34, Zip_Code#1328]
#       :     :           +- RangeJoin geom#1253: geometry, geometry#1313: geometry, WITHIN
#       :     :              :- Union
#       :     :              :  :- Project [DR_NO#29, AREA NAME#34,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#1253]
#       :     :              :  :  +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :     :              :  :     +- FileScan csv [DR_NO#29,AREA NAME#34,LAT#55,LON#56] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#       :     :              :  +- Project [DR_NO#103, AREA NAME#108,  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#2310]
#       :     :              :     +- Filter isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )
#       :     :              :        +- FileScan csv [DR_NO#103,AREA NAME#108,LAT#129,LON#130] Batched: false, DataFilters: [isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  )], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/CrimeData/Crime_D..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DR_NO:int,AREA NAME:string,LAT:double,LON:double>
#       :     :              +- Filter isnotnull(geometry#1313)
#       :     :                 +- ObjectHashAggregate(keys=[ZCTA10#1037], functions=[st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)], output=[Zip_Code#1328, geometry#1313])
#       :     :                    +- Exchange hashpartitioning(ZCTA10#1037, 1000), ENSURE_REQUIREMENTS, [plan_id=9374]
#       :     :                       +- ObjectHashAggregate(keys=[ZCTA10#1037], functions=[partial_st_union_aggr(geometry#1007, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@7450dfc6, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)], output=[ZCTA10#1037, buf#1352])
#       :     :                          +- Project [features#1004.properties.ZCTA10 AS ZCTA10#1037, features#1004.geometry AS geometry#1007]
#       :     :                             +- Filter isnotnull(features#1004.properties.ZCTA10)
#       :     :                                +- Generate explode(features#996), false, [features#1004]
#       :     :                                   +- Filter ((size(features#996, true) > 0) AND isnotnull(features#996))
#       :     :                                      +- FileScan geojson [features#996] Batched: false, DataFilters: [(size(features#996, true) > 0), isnotnull(features#996)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       :     +- HashAggregate(keys=[Zip_Code#1141], functions=[sum(Population#1142L)], output=[Zip_Code#1141, Total_Population#1148L], schema specialized)
#       :        +- Exchange hashpartitioning(Zip_Code#1141, 1000), ENSURE_REQUIREMENTS, [plan_id=9350]
#       :           +- HashAggregate(keys=[Zip_Code#1141], functions=[partial_sum(Population#1142L)], output=[Zip_Code#1141, sum#1158L], schema specialized)
#       :              +- Project [features#1004.properties.ZCTA10 AS Zip_Code#1141, features#1004.properties.POP_2010 AS Population#1142L]
#       :                 +- Filter isnotnull(features#1004.properties.ZCTA10)
#       :                    +- Generate explode(features#2230), false, [features#1004]
#       :                       +- Filter ((size(features#2230, true) > 0) AND isnotnull(features#2230))
#       :                          +- FileScan geojson [features#2230] Batched: false, DataFilters: [(size(features#2230, true) > 0), isnotnull(features#2230)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Block..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:...
#       +- Project [Zip Code#205 AS Zip_Code#421, Community#206, cast(regexp_replace(cast(cast(regexp_replace(cast(cast(regexp_replace(Estimated Median Income#207, [$,], , 1) as double) as string), [$,], , 1) as double) as string), [$,], , 1) as double) AS Median_Income#1177]
#          +- Filter isnotnull(Zip Code#205)
#             +- FileScan csv [Zip Code#205,Community#206,Estimated Median Income#207] Batched: false, DataFilters: [isnotnull(Zip Code#205)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv], PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Community:string,Estimated Median Income:string>
#
# Shuffle Replicate NL Join Time: 521.14 seconds

# %%
print(f"Broadcast Join Time: {elapsed_time_broadcast:.2f} seconds")
print(f"Merge Join Time: {elapsed_time_merge:.2f} seconds")
print(f"Suffle Hash Join Time: {elapsed_time_shuffle_hash:.2f} seconds")
print(f"Shuffle Replicate NL Join Time: {elapsed_time_shuffle_replicate:.2f} seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Broadcast Join Time: 635.54 seconds
# Merge Join Time: 433.70 seconds
# Suffle Hash Join Time: 565.34 seconds
# Shuffle Replicate NL Join Time: 521.14 seconds
